# %%
# Lecture de la carte depuis un fichier

fichier = open("carte.txt", 'r') # ouvrir un fichier en mode lecture "r" pour "read"

for ligne in fichier: # Se ballader dans un fichier, attention toute lue est oubliée
    print("nouvelle ligne" + ligne)

# Stocker le contenu texte
# Out:
# nouvelle ligne    A-------------------P
#
# nouvelle ligne     \                 /
#
# nouvelle ligne      \               /
#
# nouvelle ligne       B-------------C
#
# nouvelle ligne       |             |
#
# nouvelle ligne       |             |
#
# nouvelle ligne       D             E-------F
#
# nouvelle ligne       |             |       |
#
# nouvelle ligne       |             |       |
#
# nouvelle ligneH------I-------------G-------J

# %%
# Afficher les positions de chaque ville
# Qu'est ce qui caracterise de façon unique chaque ville, en dehors de son nom ?
# Essayer de stocker les valeurs uniques de chaque ville

# %%
# Calculer la distance entre deux villes (truc: Pythagore est utile :DD )
# Aidez vous de dessin.
# Attention chaque caractere equivaut à un carré (aussi large que haut)
# par les couples A,B et C,D suivants sont à une même distance
# A--B 
#
# C
# |
# |
# D
#

# %%
# Stocker la distance entre toutes les villes (un tableau serait bien utile aussi)
#

# %%
# A suivre ....
